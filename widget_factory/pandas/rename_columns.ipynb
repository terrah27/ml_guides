# %% [markdown]
# ## Renaming Columns
#
# This notebook accompanies the article [How to Rename Column Headers](https://python.plainenglish.io/how-to-rename-column-headings-with-pandas-a13355d96d15).

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.dates import DateFormatter
from collections import Counter

import warnings
warnings.filterwarnings('ignore')

# %%
# read in worker data
worker_df = pd.read_csv('../data/workers.csv')
print(worker_df.shape)
worker_df.head()
# Out:
# (5000, 5)
#    Worker ID      Worker Name   Hire Date Worker Status            Team
# 0       1000       Paul Clark  2020-09-12     Part Time        SeaGreen
# 1       1001     Andrea White  2001-11-08     Full Time         Crimson
# 2       1002    Daniel Taylor  2002-06-10     Part Time  LightSteelBlue
# 3       1003      Ann Manning  2019-09-13      Per Diem         Crimson
# 4       1004  Brenda Gonzales  2000-12-23     Part Time         Crimson

# %% [markdown]
# #### Pandas Rename Method

# %%
# rename one column only
worker_df_renamed = worker_df.rename(columns={'Worker ID':'worker_id'})
worker_df_renamed.head()
# Out:
#    worker_id      Worker Name   Hire Date Worker Status            Team
# 0       1000       Paul Clark  2020-09-12     Part Time        SeaGreen
# 1       1001     Andrea White  2001-11-08     Full Time         Crimson
# 2       1002    Daniel Taylor  2002-06-10     Part Time  LightSteelBlue
# 3       1003      Ann Manning  2019-09-13      Per Diem         Crimson
# 4       1004  Brenda Gonzales  2000-12-23     Part Time         Crimson

# %%
# rename columns out of order
worker_df_renamed = worker_df.rename(columns={'Worker Name':'worker_name',
                                              'Team':'team',
                                              'Worker Status':'worker_status',
                                              'Hire Date':'hire_date',
                                              'Worker ID':'worker_id'})
worker_df_renamed.head()
# Out:
#    worker_id      worker_name   hire_date worker_status            team
# 0       1000       Paul Clark  2020-09-12     Part Time        SeaGreen
# 1       1001     Andrea White  2001-11-08     Full Time         Crimson
# 2       1002    Daniel Taylor  2002-06-10     Part Time  LightSteelBlue
# 3       1003      Ann Manning  2019-09-13      Per Diem         Crimson
# 4       1004  Brenda Gonzales  2000-12-23     Part Time         Crimson

# %%
# rename columns extra columns
# errors = ignore will ignore extra columns and raise will cause an error
worker_df_renamed = worker_df.rename(columns={'Worker Name':'worker_name',
                                              'Worker DOB':'worker_dob',
                                              'Termination Date':'termination_date',
                                              'Team':'team',
                                              'Worker Status':'worker_status',
                                              'Hire Date':'hire_date',
                                              'Worker ID':'worker_id'}, errors='raise')
worker_df_renamed.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-33526990aaa4> in <module>
#       1 # rename columns extra columns
#       2 # errors = ignore will ignore extra columns and raise will cause an error
# ----> 3 worker_df_renamed = worker_df.rename(columns={'Worker Name':'worker_name',
#       4                                               'Worker DOB':'worker_dob',
#       5                                               'Termination Date':'termination_date',
#
# /usr/local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     307         @wraps(func)
#     308         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 309             return func(*args, **kwargs)
#     310
#     311         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    4298         4  3  6
#    4299         """
# -> 4300         return super().rename(
#    4301             mapper=mapper,
#    4302             index=index,
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#     943                         if indexer[index] == -1
#     944                     ]
# --> 945                     raise KeyError(f"{missing_labels} not found in axis")
#     946
#     947             new_index = ax._transform_index(f, level)
#
# KeyError: "['Worker DOB', 'Termination Date'] not found in axis"

# %% [markdown]
# #### Assign Column Headers Directly

# %%
# assign column headers directly
worker_df.columns = ['worker_id', 'worker_name', 'hire_date', 'worker_status', 'team']
worker_df.head()
# Out:
#    worker_id      worker_name   hire_date worker_status            team
# 0       1000       Paul Clark  2020-09-12     Part Time        SeaGreen
# 1       1001     Andrea White  2001-11-08     Full Time         Crimson
# 2       1002    Daniel Taylor  2002-06-10     Part Time  LightSteelBlue
# 3       1003      Ann Manning  2019-09-13      Per Diem         Crimson
# 4       1004  Brenda Gonzales  2000-12-23     Part Time         Crimson

# %%
# we have to be careful to assign the column names in the correct order
worker_df.columns = ['worker name', 'worker id', 'hire date', 'worker status', 'team']
worker_df.head()
# Out:
#    worker name        worker id   hire date worker status            team
# 0         1000       Paul Clark  2020-09-12     Part Time        SeaGreen
# 1         1001     Andrea White  2001-11-08     Full Time         Crimson
# 2         1002    Daniel Taylor  2002-06-10     Part Time  LightSteelBlue
# 3         1003      Ann Manning  2019-09-13      Per Diem         Crimson
# 4         1004  Brenda Gonzales  2000-12-23     Part Time         Crimson
